# %% [markdown]
# ## THis notebook computes human preferences by language
# ### The input is a csv with % language spoken by country and its population and another csv with the human preferences by country

# %%
import pandas as pd
import numpy as np

# %%
## I modified manually the file
df_final=pd.read_csv("./cluster_data/proportions_population.csv")

humans=pd.read_csv("./cluster_data/human_preferences_by_country.csv")

# %%
df_final['pop_lang']=(df_final.Value*df_final.percentage)/100

# %%
humans=humans.rename(columns={'Country':'ISO3'})

humans=humans.loc[humans.Label.isin([ 'No. Characters', 'Gender', 'Fitness',
       'Social Status', 'Age', 'Species']),:]

# %%
df_weights=df_final.merge(humans,on=['ISO3'])

# %%
df_weights['est_weighted']=df_weights.Estimates*df_weights.pop_lang

df_weights['tot_pop']=df_weights.groupby(['Languages','Label'])['pop_lang'].transform('sum')

df_weights=df_weights.groupby(['Languages','Label']).agg({'est_weighted':np.sum,'tot_pop':'mean'}).reset_index()

df_weights['final_est']=df_weights.est_weighted/df_weights.tot_pop

# %%
df_weights.loc[df_weights.Languages=='es']
# Out:
#    Languages           Label  est_weighted      tot_pop  final_est
# 84        es             Age  2.266102e+08  452317774.5   0.500998
# 85        es         Fitness  8.069003e+07  452317774.5   0.178392
# 86        es          Gender  6.742212e+07  452317774.5   0.149059
# 87        es  No. Characters  2.241088e+08  452317774.5   0.495468
# 88        es   Social Status  1.809575e+08  452317774.5   0.400067
# 89        es         Species  1.984414e+08  452317774.5   0.438721

# %%
df_weights.loc[df_weights.Languages=='en']
# Out:
#    Languages           Label  est_weighted       tot_pop  final_est
# 78        en             Age  6.093152e+08  1.359135e+09   0.448311
# 79        en         Fitness  2.069360e+08  1.359135e+09   0.152256
# 80        en          Gender  1.700110e+08  1.359135e+09   0.125088
# 81        en  No. Characters  6.891511e+08  1.359135e+09   0.507051
# 82        en   Social Status  4.397645e+08  1.359135e+09   0.323562
# 83        en         Species  8.085371e+08  1.359135e+09   0.594891

# %%
df_weights.final_est=(df_weights.final_est+1)/2

df_weights.final_est=df_weights.final_est*100

# %%
df_weights.loc[df_weights.Languages=='es']
# Out:
#    Languages           Label  est_weighted      tot_pop  final_est
# 84        es             Age  2.266102e+08  452317774.5  75.049890
# 85        es         Fitness  8.069003e+07  452317774.5  58.919618
# 86        es          Gender  6.742212e+07  452317774.5  57.452959
# 87        es  No. Characters  2.241088e+08  452317774.5  74.773382
# 88        es   Social Status  1.809575e+08  452317774.5  70.003356
# 89        es         Species  1.984414e+08  452317774.5  71.936064

# %%
df_agg_final=df_weights.copy()

df_agg_final['final_est_weighted']=df_agg_final.tot_pop*df_agg_final.final_est

df_agg_final=df_agg_final.groupby(['Label']).agg({'final_est_weighted':np.sum,'tot_pop':np.sum}).reset_index()

df_agg_final['human_agg_by_pop']=df_agg_final.final_est_weighted/df_agg_final.tot_pop

# %%
df_agg_final
# Out:
#             Label  final_est_weighted       tot_pop  human_agg_by_pop
# 0             Age        5.353072e+11  7.477710e+09         71.587055
# 1         Fitness        4.271590e+11  7.477710e+09         57.124310
# 2          Gender        4.164054e+11  7.477710e+09         55.686228
# 3  No. Characters        5.540026e+11  7.477710e+09         74.087209
# 4   Social Status        4.993423e+11  7.477710e+09         66.777441
# 5         Species        5.968958e+11  7.477710e+09         79.823346

# %%
df_weights_formatted=df_weights.pivot(index='Label',columns='Languages',values='final_est')

# %%
df_weights.to_csv("human_preferences_by_lang_unpivoted.csv",index=False)

df_weights_formatted.to_csv("human_preferences_by_lang_converted.csv")

# %%
df_weights_formatted
# Out:
# Languages              af         ar         az         be         bg  \
# Label
# Age             75.062129  71.826936  74.404850  74.618049  76.562218
# Fitness         59.067847  56.686353  58.850723  58.257658  59.633063
# Gender          57.032231  54.343770  54.920952  51.363462  54.666919
# No. Characters  77.067028  74.164764  72.707220  73.332358  75.451048
# Social Status   69.663674  66.212128  66.063507  66.392904  68.762867
# Species         79.372922  80.024098  65.105577  81.083481  81.005535
#
# Languages              bn         bs         ca         cs         da  ...  \
# Label                                                                  ...
# Age             70.811810  77.533270  74.177547  76.318762  73.645356  ...
# Fitness         58.612226  57.433867  55.253029  58.937712  57.713595  ...
# Gender          53.819616  54.702861  58.364513  56.992201  53.382696  ...
# No. Characters  74.978823  76.327764  75.831528  76.574638  75.553021  ...
# Social Status   68.115838  65.068156  62.871066  70.815834  65.040542  ...
# Species         78.501816  79.777624  77.811273  79.709316  84.637363  ...
#
# Languages              tr         uk         ur         uz         vi  \
# Label
# Age             74.757768  72.762119  69.784060  76.491558  72.725283
# Fitness         58.993229  58.450191  55.757425  56.531640  57.972196
# Gender          55.387918  53.084437  54.111415  51.393634  56.824730
# No. Characters  72.798477  72.152212  75.330536  79.915713  73.620520
# Social Status   66.707610  66.977199  61.810494  70.931468  68.981515
# Species         68.850058  80.044235  80.211305  79.628223  77.722530
#
# Languages              xh         yo      zh-cn      zh-tw         zu
# Label
# Age             75.062129  76.062757  67.698811  67.262089  75.062129
# Fitness         59.067847  51.548767  56.584632  56.549337  59.067847
# Gender          57.032231  53.239435  55.182760  54.660676  57.032231
# No. Characters  77.067028  73.774495  71.164572  69.638113  77.067028
# Social Status   69.663674  73.728380  66.723166  63.698326  69.663674
# Species         79.372922  85.857835  82.938047  77.839519  79.372922
#
# [6 rows x 80 columns]
